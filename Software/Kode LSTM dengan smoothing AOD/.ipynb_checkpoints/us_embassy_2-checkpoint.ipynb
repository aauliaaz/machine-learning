# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\AData\\kuliah\\sem 7\\Tugas Akhir\\Kode Program\\data gabungan aod cuaca pm2.5\\us_embassy_2.csv"
df_cleaned = pd.read_csv(path)
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD'] # untuk nilai 0
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA
    
df_cleaned.replace("-", pd.NA, inplace=True)

columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD'] # untuk interpolasi
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

df_cleaned = df_cleaned.dropna()

# Average smoothing untuk AOD (window=7)
df_cleaned['AOD'] = df_cleaned['AOD'].rolling(window=7, center=True).mean()

# Drop lagi NaN akibat smoothing di awal/akhir
df_cleaned = df_cleaned.dropna(subset=['AOD'])

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity  precip  windspeed  \
# 9      62.700470  2022-01-10  27.9  24.6      83.0  11.234       19.8
# 10     57.229170  2022-01-11  26.5  24.4      89.2  57.783       16.3
# 11     56.911388  2022-01-12  26.4  24.2      88.4  17.907       21.6
# 12     54.847979  2022-01-13  27.0  24.3      85.5   3.269       24.1
# 13     57.993500  2022-01-14  26.8  24.4      87.1  14.312       19.3
# ...          ...         ...   ...   ...       ...     ...        ...
# 1088   57.585364  2024-12-24  27.2  23.8      82.4  16.514       23.5
# 1089   38.936576  2024-12-25  27.1  24.3      84.9   6.508       12.9
# 1090   56.567064  2024-12-26  28.4  23.6      76.3   3.162       23.5
# 1091   54.071933  2024-12-27  28.9  23.5      73.6   0.000       17.2
# 1092   65.191038  2024-12-28  29.5  22.5      67.4   0.007       20.7
#
#            AOD
# 9     0.147036
# 10    0.161091
# 11    0.189655
# 12    0.218218
# 13    0.246782
# ...        ...
# 1088  0.633800
# 1089  0.583914
# 1090  0.518143
# 1091  0.436486
# 1092  0.338943
#
# [1084 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (182, 33, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.callbacks import Callback
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(dropout_rate),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(dropout_rate),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model


def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    all_history = {}
    all_r2_callback = {}
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    for dropout_rate in param_grid['dropout_rate']:

                        class R2History(Callback):
                            def __init__(self, val_gen):
                                self.val_gen = val_gen
                                self.r2_scores = []

                            def on_epoch_end(self, epoch, logs=None):
                                val_pred = self.model.predict(self.val_gen, verbose=0)
                                val_true_list = []
                                for i in range(len(test_gen)):
                                    _, y = val_gen[i]
                                    val_true_list.append(y)
                                val_true = np.hstack(val_true_list)
                                r2 = r2_score(val_true, val_pred)
                                self.r2_scores.append(r2)

                        r2_callback = R2History(val_gen)
                        config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}_do_{dropout_rate}"
                        print(f"\nTraining model dengan {config_name}")

                        model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate)  # ✅ Update
                        history = model.fit(train_gen, validation_data=val_gen, epochs=1, verbose=0,callbacks=[r2_callback])
                        history = model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0, callbacks=[r2_callback])

                        metrics = evaluate_model(model, test_gen)
                        print(metrics)

                        results.append({
                            'epochs': epochs,
                            'learning_rate': learning_rate,
                            'optimizer': optimizer,
                            'lstm_units': lstm_units,
                            'dropout_rate': dropout_rate,  
                            'R2': metrics['R2'],
                            'RMSE': metrics['RMSE'],
                            'MBE': metrics['MBE'],
                            'NSE': metrics['NSE']
                        })
                        models[config_name] = model
                        all_history[config_name] = history
                        all_r2_callback[config_name] = r2_callback

    return results, models, all_history, all_r2_callback

# %%
param_grid = {
    'epochs': [100],
    'learning_rate': [0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64],
    'dropout_rate': [0, 0.1, 0.2]
}

grid_results, models, all_history, all_r2_callback = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step
# {'R2': 0.6004760029927373, 'RMSE': np.float64(0.12327860762071333), 'MBE': np.float64(-0.00964825364233282), 'NSE': np.float64(-196.9174791065745)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.5757329296745766, 'RMSE': np.float64(0.12703867286983686), 'MBE': np.float64(-0.009245117182583674), 'NSE': np.float64(-192.45425222923353)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step
# {'R2': 0.43952668095608716, 'RMSE': np.float64(0.1460137507741586), 'MBE': np.float64(0.039506393608340844), 'NSE': np.float64(-164.75625862700227)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# {'R2': 0.648821137426475, 'RMSE': np.float64(0.11557940903379225), 'MBE': np.float64(-0.01344640594851943), 'NSE': np.float64(-204.99837584483575)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step
# {'R2': 0.5295130740957591, 'RMSE': np.float64(0.13377965308179035), 'MBE': np.float64(-0.021448692475213655), 'NSE': np.float64(-171.97639055743522)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# {'R2': 0.6020107575807674, 'RMSE': np.float64(0.12304159499671312), 'MBE': np.float64(-0.01122171062184242), 'NSE': np.float64(-182.4017706731134)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step
# {'R2': 0.6366088479646533, 'RMSE': np.float64(0.11757187926430142), 'MBE': np.float64(-0.019492579681191592), 'NSE': np.float64(-192.02148514591366)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# {'R2': 0.60812708660576, 'RMSE': np.float64(0.1220924780455333), 'MBE': np.float64(0.004788580029336646), 'NSE': np.float64(-196.693675839963)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# {'R2': 0.620576007354849, 'RMSE': np.float64(0.1201375249640958), 'MBE': np.float64(0.003915194059064407), 'NSE': np.float64(-199.04834068370386)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# {'R2': 0.6517509892785317, 'RMSE': np.float64(0.11509626520866213), 'MBE': np.float64(-0.016695787631285455), 'NSE': np.float64(-199.5105292767422)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# {'R2': 0.5676046640388235, 'RMSE': np.float64(0.12824982642693794), 'MBE': np.float64(-0.005456718909628085), 'NSE': np.float64(-172.0644909826727)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# {'R2': 0.4945079923992157, 'RMSE': np.float64(0.13866709974205432), 'MBE': np.float64(-0.02256213170421096), 'NSE': np.float64(-162.05142579558148)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# {'R2': 0.6501918783866705, 'RMSE': np.float64(0.11535362048680799), 'MBE': np.float64(-0.013856572531473894), 'NSE': np.float64(-203.9658009527128)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
# {'R2': 0.5507279711038633, 'RMSE': np.float64(0.13072871010264506), 'MBE': np.float64(-0.04228488053001014), 'NSE': np.float64(-191.18651360148388)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# {'R2': 0.5962384217137586, 'RMSE': np.float64(0.1239306650623074), 'MBE': np.float64(-0.018729094890047978), 'NSE': np.float64(-180.65003517118234)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# {'R2': 0.5897744758540637, 'RMSE': np.float64(0.12491874859103687), 'MBE': np.float64(-0.04235396075646707), 'NSE': np.float64(-191.40400390828339)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 97ms/step
# {'R2': 0.5484377470297375, 'RMSE': np.float64(0.1310614900598814), 'MBE': np.float64(-0.007026109428969504), 'NSE': np.float64(-168.5812012224735)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step
# {'R2': 0.5844303691042971, 'RMSE': np.float64(0.12572978905210366), 'MBE': np.float64(0.0032321986685282336), 'NSE': np.float64(-174.6862554519486)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# {'R2': 0.6120875864052736, 'RMSE': np.float64(0.1214739417993287), 'MBE': np.float64(-0.025049449099065375), 'NSE': np.float64(-191.03649890754838)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 57ms/step
# {'R2': 0.6129795776205997, 'RMSE': np.float64(0.12133419884990533), 'MBE': np.float64(0.0034226399566934223), 'NSE': np.float64(-185.5340131896746)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step
# {'R2': 0.48095284390270054, 'RMSE': np.float64(0.14051403124291614), 'MBE': np.float64(-0.04247608422385551), 'NSE': np.float64(-171.64920392251906)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 70ms/step
# {'R2': 0.6460683039536732, 'RMSE': np.float64(0.11603152875031435), 'MBE': np.float64(-0.0017728985427686453), 'NSE': np.float64(-187.64802438771596)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# {'R2': 0.6145521204648189, 'RMSE': np.float64(0.12108744515426334), 'MBE': np.float64(-0.0018540500442249454), 'NSE': np.float64(-182.65035582610895)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# {'R2': 0.5558630313235977, 'RMSE': np.float64(0.1299794657791714), 'MBE': np.float64(-0.015274538896398484), 'NSE': np.float64(-172.068247416315)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step
# {'R2': 0.6298360690022429, 'RMSE': np.float64(0.1186624565607451), 'MBE': np.float64(-0.006725565907202279), 'NSE': np.float64(-204.89522813128215)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step
# {'R2': 0.56552995231321, 'RMSE': np.float64(0.12855714126504822), 'MBE': np.float64(-0.02163704938005484), 'NSE': np.float64(-191.02578867800176)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# {'R2': 0.6102240079153965, 'RMSE': np.float64(0.12176537999965775), 'MBE': np.float64(-0.00019999290622321097), 'NSE': np.float64(-190.9859482580629)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# {'R2': 0.5951797299266931, 'RMSE': np.float64(0.12409303623637713), 'MBE': np.float64(-0.015604484188444304), 'NSE': np.float64(-177.54904585299428)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# {'R2': 0.538876714233681, 'RMSE': np.float64(0.1324417200788493), 'MBE': np.float64(-0.05040176944098694), 'NSE': np.float64(-190.31745992728872)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.5375021291968733, 'RMSE': np.float64(0.1326389741992614), 'MBE': np.float64(0.019118135793463786), 'NSE': np.float64(-166.39555825211775)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# {'R2': 0.47806707480365884, 'RMSE': np.float64(0.14090410081496862), 'MBE': np.float64(-0.08083775547945118), 'NSE': np.float64(-240.02203358295932)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# {'R2': 0.647210951367172, 'RMSE': np.float64(0.115844076891719), 'MBE': np.float64(-0.02376708897234228), 'NSE': np.float64(-202.04132480426873)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# {'R2': 0.5172783188370984, 'RMSE': np.float64(0.13550792287949995), 'MBE': np.float64(-0.023181088798503103), 'NSE': np.float64(-166.4104476073741)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 90ms/step
# {'R2': 0.5596730605988142, 'RMSE': np.float64(0.12942075049752857), 'MBE': np.float64(-0.008353658550242605), 'NSE': np.float64(-171.67223159039196)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 96ms/step
# {'R2': 0.5943980455000238, 'RMSE': np.float64(0.12421278667885186), 'MBE': np.float64(-0.03772642605382443), 'NSE': np.float64(-196.59976189995834)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# {'R2': 0.4639595648257626, 'RMSE': np.float64(0.14279567745028915), 'MBE': np.float64(-0.004564743407158435), 'NSE': np.float64(-155.2857156979657)}

# %%
print(1)
# Out:
# 1

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units  dropout_rate        R2  \
# 0      100          0.001      adam          16           0.0  0.600476
# 1      100          0.001      adam          16           0.1  0.575733
# 2      100          0.001      adam          16           0.2  0.439527
# 3      100          0.001      adam          32           0.0  0.648821
# 4      100          0.001      adam          32           0.1  0.529513
# 5      100          0.001      adam          32           0.2  0.602011
# 6      100          0.001      adam          64           0.0  0.636609
# 7      100          0.001      adam          64           0.1  0.608127
# 8      100          0.001      adam          64           0.2  0.620576
# 9      100          0.001   rmsprop          16           0.0  0.651751
# 10     100          0.001   rmsprop          16           0.1  0.567605
# 11     100          0.001   rmsprop          16           0.2  0.494508
# 12     100          0.001   rmsprop          32           0.0  0.650192
# 13     100          0.001   rmsprop          32           0.1  0.550728
# 14     100          0.001   rmsprop          32           0.2  0.596238
# 15     100          0.001   rmsprop          64           0.0  0.589774
# 16     100          0.001   rmsprop          64           0.1  0.548438
# 17     100          0.001   rmsprop          64           0.2  0.584430
# 18     100          0.010      adam          16           0.0  0.612088
# 19     100          0.010      adam          16           0.1  0.612980
# 20     100          0.010      adam          16           0.2  0.480953
# 21     100          0.010      adam          32           0.0  0.646068
# 22     100          0.010      adam          32           0.1  0.614552
# 23     100          0.010      adam          32           0.2  0.555863
# 24     100          0.010      adam          64           0.0  0.629836
# 25     100          0.010      adam          64           0.1  0.565530
# 26     100          0.010      adam          64           0.2  0.610224
# 27     100          0.010   rmsprop          16           0.0  0.595180
# 28     100          0.010   rmsprop          16           0.1  0.538877
# 29     100          0.010   rmsprop          16           0.2  0.537502
# 30     100          0.010   rmsprop          32           0.0  0.478067
# 31     100          0.010   rmsprop          32           0.1  0.647211
# 32     100          0.010   rmsprop          32           0.2  0.517278
# 33     100          0.010   rmsprop          64           0.0  0.559673
# 34     100          0.010   rmsprop          64           0.1  0.594398
# 35     100          0.010   rmsprop          64           0.2  0.463960
#
#         RMSE       MBE         NSE
# 0   0.123279 -0.009648 -196.917479
# 1   0.127039 -0.009245 -192.454252
# 2   0.146014  0.039506 -164.756259
# 3   0.115579 -0.013446 -204.998376
# 4   0.133780 -0.021449 -171.976391
# 5   0.123042 -0.011222 -182.401771
# 6   0.117572 -0.019493 -192.021485
# 7   0.122092  0.004789 -196.693676
# 8   0.120138  0.003915 -199.048341
# 9   0.115096 -0.016696 -199.510529
# 10  0.128250 -0.005457 -172.064491
# 11  0.138667 -0.022562 -162.051426
# 12  0.115354 -0.013857 -203.965801
# 13  0.130729 -0.042285 -191.186514
# 14  0.123931 -0.018729 -180.650035
# 15  0.124919 -0.042354 -191.404004
# 16  0.131061 -0.007026 -168.581201
# 17  0.125730  0.003232 -174.686255
# 18  0.121474 -0.025049 -191.036499
# 19  0.121334  0.003423 -185.534013
# 20  0.140514 -0.042476 -171.649204
# 21  0.116032 -0.001773 -187.648024
# 22  0.121087 -0.001854 -182.650356
# 23  0.129979 -0.015275 -172.068247
# 24  0.118662 -0.006726 -204.895228
# 25  0.128557 -0.021637 -191.025789
# 26  0.121765 -0.000200 -190.985948
# 27  0.124093 -0.015604 -177.549046
# 28  0.132442 -0.050402 -190.317460
# 29  0.132639  0.019118 -166.395558
# 30  0.140904 -0.080838 -240.022034
# 31  0.115844 -0.023767 -202.041325
# 32  0.135508 -0.023181 -166.410448
# 33  0.129421 -0.008354 -171.672232
# 34  0.124213 -0.037726 -196.599762
# 35  0.142796 -0.004565 -155.285716

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{best_config['dropout_rate']}"
if best_config['dropout_rate'] == 0.0:
    best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{0}"
best_model = models[best_model_name]
best_history = all_history[best_model_name]
best_r2_callback = all_r2_callback[best_model_name]

best_model.save("us_embassy_2.keras")

# %%
best_model_name
# Out:
# 'epochs_100_lr_0.001_opt_rmsprop_units_16_do_0'

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.0154
# Test Loss: 0.013247150927782059

# %%
from tensorflow.keras.models import load_model

best_model = load_model("us_embassy_2.keras")

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)

# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mae = mean_absolute_error(test_true, test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²  : {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE : {test_mae:.4f}")
print(f"Test NSE : {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
#
# Testing Metrics:
# Test R²  : 0.6518
# Test RMSE: 0.1151
# Test MAE : 0.0815
# Test NSE : -199.5105

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.xticks(rotation=45) 
import matplotlib.dates as mdates
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=90)) 
plt.legend()
plt.show()
# Out:
#  10/264 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
df_results.to_csv("us_embassy_2 results.csv", index=False)

# %%
loss = best_history.history['loss']
val_loss = best_history.history['val_loss']
r2_scores = best_r2_callback.r2_scores

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()
