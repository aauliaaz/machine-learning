# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\AData\\kuliah\\sem 7\\Tugas Akhir\\Kode Program\\data gabungan aod cuaca pm2.5\\us_embassy_1.csv"
df_cleaned = pd.read_csv(path)
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD'] # untuk nilai 0
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA
    
df_cleaned.replace("-", pd.NA, inplace=True)

columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD'] # untuk interpolasi
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

df_cleaned = df_cleaned.dropna()

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity  precip  windspeed  \
# 5      86.553885  2022-01-06  81.7  77.2      87.0   0.542       11.4
# 6      80.154021  2022-01-07  82.6  74.8      79.2   0.012       10.6
# 7      58.667845  2022-01-08  83.2  75.7      79.4   0.000       13.0
# 8      67.603541  2022-01-09  83.9  76.0      77.9   0.000       18.3
# 9      53.946860  2022-01-10  82.4  76.3      82.4   0.434       12.3
# ...          ...         ...   ...   ...       ...     ...        ...
# 1091   55.361074  2024-12-27  29.0  23.6      73.5   0.000       18.3
# 1092   67.081319  2024-12-28  29.6  22.6      67.5   0.000       20.6
# 1093   62.004489  2024-12-29  29.1  23.9      73.7   0.001       15.5
# 1094   53.755123  2024-12-30  28.1  23.2      75.3   1.007       29.0
# 1095   36.754918  2024-12-31  28.1  23.2      75.4   1.611       23.9
#
#            AOD
# 5     0.328900
# 6     0.078600
# 7     0.118000
# 8     0.570800
# 9     0.535267
# ...        ...
# 1091  0.379600
# 1092  0.412400
# 1093  0.314400
# 1094  0.216400
# 1095  0.216400
#
# [1091 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (184, 34, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.callbacks import Callback
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(dropout_rate),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(dropout_rate),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model


def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    all_history = {}
    all_r2_callback = {}
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    for dropout_rate in param_grid['dropout_rate']:

                        class R2History(Callback):
                            def __init__(self, val_gen):
                                self.val_gen = val_gen
                                self.r2_scores = []

                            def on_epoch_end(self, epoch, logs=None):
                                val_pred = self.model.predict(self.val_gen, verbose=0)
                                val_true_list = []
                                for i in range(len(test_gen)):
                                    _, y = val_gen[i]
                                    val_true_list.append(y)
                                val_true = np.hstack(val_true_list)
                                r2 = r2_score(val_true, val_pred)
                                self.r2_scores.append(r2)

                        r2_callback = R2History(val_gen)
                        config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}_do_{dropout_rate}"
                        print(f"\nTraining model dengan {config_name}")

                        model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate)  # ✅ Update
                        history = model.fit(train_gen, validation_data=val_gen, epochs=1, verbose=0,callbacks=[r2_callback])
                        history = model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0, callbacks=[r2_callback])

                        metrics = evaluate_model(model, test_gen)
                        print(metrics)

                        results.append({
                            'epochs': epochs,
                            'learning_rate': learning_rate,
                            'optimizer': optimizer,
                            'lstm_units': lstm_units,
                            'dropout_rate': dropout_rate,  
                            'R2': metrics['R2'],
                            'RMSE': metrics['RMSE'],
                            'MBE': metrics['MBE'],
                            'NSE': metrics['NSE']
                        })
                        models[config_name] = model
                        all_history[config_name] = history
                        all_r2_callback[config_name] = r2_callback

    return results, models, all_history, all_r2_callback

# %%
param_grid = {
    'epochs': [100],
    'learning_rate': [0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64],
    'dropout_rate': [0, 0.1, 0.2]
}

grid_results, models, all_history, all_r2_callback = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 14/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# {'R2': -0.10205081580738895, 'RMSE': np.float64(0.2033979433238349), 'MBE': np.float64(0.1299826602946591), 'NSE': np.float64(-327.1202420601904)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# {'R2': 0.49584056188713255, 'RMSE': np.float64(0.1375718881418674), 'MBE': np.float64(-0.05463490135914921), 'NSE': np.float64(-216.19333926181142)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# {'R2': 0.29206939683627986, 'RMSE': np.float64(0.16302007568894678), 'MBE': np.float64(-0.044867835692809194), 'NSE': np.float64(-179.77984051429164)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'R2': 0.43939600690074143, 'RMSE': np.float64(0.1450687404833792), 'MBE': np.float64(0.037714178995929874), 'NSE': np.float64(-265.5454944593356)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# {'R2': 0.5270693456274691, 'RMSE': np.float64(0.1332430236602186), 'MBE': np.float64(-0.022514801805793745), 'NSE': np.float64(-197.5969561803811)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'R2': 0.44276798547603136, 'RMSE': np.float64(0.14463179525378986), 'MBE': np.float64(-0.042311997355158185), 'NSE': np.float64(-199.20006440463237)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# {'R2': 0.5270611492874642, 'RMSE': np.float64(0.1332441782696559), 'MBE': np.float64(0.029614913213008475), 'NSE': np.float64(-230.66042370300767)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'R2': 0.48610111030863534, 'RMSE': np.float64(0.1388943522379809), 'MBE': np.float64(-0.024384023775680806), 'NSE': np.float64(-189.02766517146867)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'R2': 0.41155048419413076, 'RMSE': np.float64(0.1486279035388409), 'MBE': np.float64(-0.0720621321234676), 'NSE': np.float64(-230.22829141319954)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# {'R2': 0.0922966612379893, 'RMSE': np.float64(0.18459405641984972), 'MBE': np.float64(0.11273174569891388), 'NSE': np.float64(-326.21148301961796)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# {'R2': 0.39162227837928965, 'RMSE': np.float64(0.1511236373892625), 'MBE': np.float64(0.0498470679179148), 'NSE': np.float64(-176.87955431336783)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'R2': 0.06565772619049293, 'RMSE': np.float64(0.18728316768752593), 'MBE': np.float64(0.1111660184385362), 'NSE': np.float64(-197.25304438757777)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'R2': 0.28596817061379154, 'RMSE': np.float64(0.16372105437883971), 'MBE': np.float64(0.08843448324664704), 'NSE': np.float64(-291.99778744580425)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# {'R2': 0.5239321614690875, 'RMSE': np.float64(0.1336842267999912), 'MBE': np.float64(-0.025432629526789048), 'NSE': np.float64(-219.883523031887)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step
# {'R2': 0.4051455587066728, 'RMSE': np.float64(0.14943457791695494), 'MBE': np.float64(-0.045971442623294674), 'NSE': np.float64(-214.33415040220135)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# {'R2': 0.4753797620018102, 'RMSE': np.float64(0.1403357328979902), 'MBE': np.float64(0.05197029375696451), 'NSE': np.float64(-240.47386080434467)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# {'R2': 0.27149011253375577, 'RMSE': np.float64(0.16537256869062694), 'MBE': np.float64(-0.09671170493742001), 'NSE': np.float64(-253.06809813498907)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# {'R2': 0.4288405977310823, 'RMSE': np.float64(0.1464280949627685), 'MBE': np.float64(-0.06738644664709387), 'NSE': np.float64(-205.37576684892107)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units  dropout_rate          R2  \
# 0      100          0.001      adam          16           0.0   -0.102051
# 1      100          0.001      adam          16           0.1    0.495841
# 2      100          0.001      adam          16           0.2    0.292069
# 3      100          0.001      adam          32           0.0    0.439396
# 4      100          0.001      adam          32           0.1    0.527069
# 5      100          0.001      adam          32           0.2    0.442768
# 6      100          0.001      adam          64           0.0    0.527061
# 7      100          0.001      adam          64           0.1    0.486101
# 8      100          0.001      adam          64           0.2    0.411550
# 9      100          0.001   rmsprop          16           0.0    0.092297
# 10     100          0.001   rmsprop          16           0.1    0.391622
# 11     100          0.001   rmsprop          16           0.2    0.065658
# 12     100          0.001   rmsprop          32           0.0    0.285968
# 13     100          0.001   rmsprop          32           0.1    0.523932
# 14     100          0.001   rmsprop          32           0.2    0.405146
# 15     100          0.001   rmsprop          64           0.0    0.475380
# 16     100          0.001   rmsprop          64           0.1    0.271490
# 17     100          0.001   rmsprop          64           0.2    0.428841
# 18     100          0.010      adam          16           0.0    0.477008
# 19     100          0.010      adam          16           0.1    0.256258
# 20     100          0.010      adam          16           0.2    0.523311
# 21     100          0.010      adam          32           0.0    0.260513
# 22     100          0.010      adam          32           0.1    0.371282
# 23     100          0.010      adam          32           0.2    0.564035
# 24     100          0.010      adam          64           0.0 -106.402393
# 25     100          0.010      adam          64           0.1    0.463658
# 26     100          0.010      adam          64           0.2    0.510259
# 27     100          0.010   rmsprop          16           0.0    0.611312
# 28     100          0.010   rmsprop          16           0.1    0.461956
# 29     100          0.010   rmsprop          16           0.2    0.496911
# 30     100          0.010   rmsprop          32           0.0    0.478653
# 31     100          0.010   rmsprop          32           0.1    0.240954
# 32     100          0.010   rmsprop          32           0.2    0.453004
# 33     100          0.010   rmsprop          64           0.0    0.539994
# 34     100          0.010   rmsprop          64           0.1    0.585914
# 35     100          0.010   rmsprop          64           0.2    0.474164
#
#         RMSE       MBE           NSE
# 0   0.203398  0.129983   -327.120242
# 1   0.137572 -0.054635   -216.193339
# 2   0.163020 -0.044868   -179.779841
# 3   0.145069  0.037714   -265.545494
# 4   0.133243 -0.022515   -197.596956
# 5   0.144632 -0.042312   -199.200064
# 6   0.133244  0.029615   -230.660424
# 7   0.138894 -0.024384   -189.027665
# 8   0.148628 -0.072062   -230.228291
# 9   0.184594  0.112732   -326.211483
# 10  0.151124  0.049847   -176.879554
# 11  0.187283  0.111166   -197.253044
# 12  0.163721  0.088434   -291.997787
# 13  0.133684 -0.025433   -219.883523
# 14  0.149435 -0.045971   -214.334150
# 15  0.140336  0.051970   -240.473861
# 16  0.165373 -0.096712   -253.068098
# 17  0.146428 -0.067386   -205.375767
# 18  0.140118  0.036694   -265.419050
# 19  0.167092 -0.090528   -238.498514
# 20  0.133771  0.003582   -198.000057
# 21  0.166614 -0.073428   -290.840287
# 22  0.153629  0.047145   -254.210402
# 23  0.127930 -0.005440   -210.073136
# 24  2.007949 -0.392721 -14075.584177
# 25  0.141895 -0.055594   -213.955031
# 26  0.135590 -0.033665   -220.317360
# 27  0.120794  0.003201   -208.278151
# 28  0.142120 -0.067676   -231.492779
# 29  0.137426  0.027815   -198.141778
# 30  0.139897 -0.058635   -200.479625
# 31  0.168803 -0.097220   -260.666550
# 32  0.143297 -0.069456   -212.596357
# 33  0.131410  0.017399   -194.994968
# 34  0.124678 -0.026312   -227.402231
# 35  0.140498 -0.014024   -163.386602

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{best_config['dropout_rate']}"
if best_config['dropout_rate'] == 0.0:
    best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{0}"
best_model = models[best_model_name]
best_history = all_history[best_model_name]
best_r2_callback = all_r2_callback[best_model_name]

best_model.save("us_embassy_1.keras")

# %%
best_model_name
# Out:
# 'epochs_100_lr_0.01_opt_rmsprop_units_16_do_0'

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0132
# Test Loss: 0.014591258019208908

# %%
from tensorflow.keras.models import load_model

best_model = load_model("us_embassy_1.keras")

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)

# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mae = mean_absolute_error(test_true, test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²  : {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE : {test_mae:.4f}")
print(f"Test NSE : {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
#
# Testing Metrics:
# Test R²  : 0.6113
# Test RMSE: 0.1208
# Test MAE : 0.0914
# Test NSE : -208.2782

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.xticks(rotation=45) 
import matplotlib.dates as mdates
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=90)) 
plt.legend()
plt.show()
# Out:
#  33/266 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 266/266 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
df_results.to_csv("us_embassy_1 results.csv", index=False)

# %%
loss = best_history.history['loss']
val_loss = best_history.history['val_loss']
r2_scores = best_r2_callback.r2_scores

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()
