# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\AData\\kuliah\\sem 7\\Tugas Akhir\\Kode Program\\data gabungan aod cuaca pm2.5\\kebun_jeruk.csv"
df_cleaned = pd.read_csv(path)
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD'] # untuk nilai 0
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA
    
df_cleaned.replace("-", pd.NA, inplace=True)

columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD'] # untuk interpolasi
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

df_cleaned = df_cleaned.dropna()

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity  precip  windspeed  \
# 11     51.750000  2022-01-12  26.5  24.3      88.9  17.599       25.9
# 12     50.833333  2022-01-13  26.9  24.2      85.8   4.394       24.1
# 13     52.916667  2022-01-14  26.7  24.4      87.5  13.717       20.6
# 14     59.833333  2022-01-15  26.8  24.7      88.6   4.661       17.3
# 15     66.966667  2022-01-16  27.2  25.5      90.6   8.146       15.1
# ...          ...         ...   ...   ...       ...     ...        ...
# 1091   54.222222  2024-12-27  28.7  23.7      75.3   0.000       16.7
# 1092   47.750000  2024-12-28  29.3  23.0      69.9   0.007       18.5
# 1093   41.277778  2024-12-29  28.8  24.0      75.9   0.045       16.7
# 1094   34.805556  2024-12-30  27.7  23.3      77.5   2.841       25.6
# 1095   28.333333  2024-12-31  27.8  23.2      76.8   3.955       25.8
#
#            AOD
# 11    0.380600
# 12    0.342756
# 13    0.304911
# 14    0.267067
# 15    0.229222
# ...        ...
# 1091  0.364600
# 1092  0.498600
# 1093  0.372900
# 1094  0.247200
# 1095  0.247200
#
# [1085 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (183, 33, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.callbacks import Callback
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(dropout_rate),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(dropout_rate),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model


def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    all_history = {}
    all_r2_callback = {}
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    for dropout_rate in param_grid['dropout_rate']:

                        class R2History(Callback):
                            def __init__(self, val_gen):
                                self.val_gen = val_gen
                                self.r2_scores = []

                            def on_epoch_end(self, epoch, logs=None):
                                val_pred = self.model.predict(self.val_gen, verbose=0)
                                val_true_list = []
                                for i in range(len(test_gen)):
                                    _, y = val_gen[i]
                                    val_true_list.append(y)
                                val_true = np.hstack(val_true_list)
                                r2 = r2_score(val_true, val_pred)
                                self.r2_scores.append(r2)

                        r2_callback = R2History(val_gen)
                        config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}_do_{dropout_rate}"
                        print(f"\nTraining model dengan {config_name}")

                        model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate)  # ✅ Update
                        history = model.fit(train_gen, validation_data=val_gen, epochs=1, verbose=0,callbacks=[r2_callback])
                        history = model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0, callbacks=[r2_callback])

                        metrics = evaluate_model(model, test_gen)
                        print(metrics)

                        results.append({
                            'epochs': epochs,
                            'learning_rate': learning_rate,
                            'optimizer': optimizer,
                            'lstm_units': lstm_units,
                            'dropout_rate': dropout_rate,  
                            'R2': metrics['R2'],
                            'RMSE': metrics['RMSE'],
                            'MBE': metrics['MBE'],
                            'NSE': metrics['NSE']
                        })
                        models[config_name] = model
                        all_history[config_name] = history
                        all_r2_callback[config_name] = r2_callback

    return results, models, all_history, all_r2_callback

# %%
param_grid = {
    'epochs': [100],
    'learning_rate': [0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64],
    'dropout_rate': [0, 0.1, 0.2]
}

grid_results, models, all_history, all_r2_callback = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 3s 104ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step
# {'R2': 0.680186690228685, 'RMSE': np.float64(0.10693679291241523), 'MBE': np.float64(-0.016560465615310657), 'NSE': np.float64(-202.6072557119713)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step
# {'R2': 0.6525295994103248, 'RMSE': np.float64(0.11146481402235597), 'MBE': np.float64(-0.0342785218599473), 'NSE': np.float64(-189.97643598893225)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# {'R2': 0.5011785209760143, 'RMSE': np.float64(0.13355232749811885), 'MBE': np.float64(-0.0376322795047145), 'NSE': np.float64(-161.26608432756103)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step
# {'R2': 0.6082859987593614, 'RMSE': np.float64(0.11834868474141756), 'MBE': np.float64(-0.0012022265366109972), 'NSE': np.float64(-183.97485343273783)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step
# {'R2': 0.6215483905301113, 'RMSE': np.float64(0.1163279477968297), 'MBE': np.float64(-0.006942906114716012), 'NSE': np.float64(-175.54849419996063)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step
# {'R2': 0.6452321263347124, 'RMSE': np.float64(0.11262920814920004), 'MBE': np.float64(-0.010333532123546872), 'NSE': np.float64(-200.22003978671492)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step
# {'R2': 0.5616696939876786, 'RMSE': np.float64(0.12519288211392557), 'MBE': np.float64(-0.00849514489711119), 'NSE': np.float64(-182.89247491187245)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step
# {'R2': 0.6008372378916904, 'RMSE': np.float64(0.11946863395804873), 'MBE': np.float64(-0.02234940694084707), 'NSE': np.float64(-175.75682092656584)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step
# {'R2': 0.547692024554161, 'RMSE': np.float64(0.12717332056119543), 'MBE': np.float64(-0.01484687088775889), 'NSE': np.float64(-172.49951819712777)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# {'R2': 0.711817132285499, 'RMSE': np.float64(0.10151096763601565), 'MBE': np.float64(-0.01290460549818834), 'NSE': np.float64(-198.95592410355354)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step
# {'R2': 0.6953025298145796, 'RMSE': np.float64(0.10437904342698753), 'MBE': np.float64(-0.014085141097555284), 'NSE': np.float64(-195.6529658382154)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# {'R2': 0.4904824041598832, 'RMSE': np.float64(0.13497659917495392), 'MBE': np.float64(0.04333794087426088), 'NSE': np.float64(-167.4743198972849)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step
# {'R2': 0.7154917416333665, 'RMSE': np.float64(0.10086170998806933), 'MBE': np.float64(0.008257983262735635), 'NSE': np.float64(-202.18568083767252)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 95ms/step
# {'R2': 0.6258634614637318, 'RMSE': np.float64(0.11566286620571994), 'MBE': np.float64(0.026961560274114487), 'NSE': np.float64(-180.144375736858)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step
# {'R2': 0.5576296503303781, 'RMSE': np.float64(0.12576850351359783), 'MBE': np.float64(0.022863256324459492), 'NSE': np.float64(-165.53316247645031)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step
# {'R2': 0.662173624201741, 'RMSE': np.float64(0.10990707888584603), 'MBE': np.float64(0.007408532115826979), 'NSE': np.float64(-184.04419610761624)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step
# {'R2': 0.7066539651790695, 'RMSE': np.float64(0.10241628051568243), 'MBE': np.float64(-0.010127448508222475), 'NSE': np.float64(-200.45607258019942)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step
# {'R2': 0.6449857840497882, 'RMSE': np.float64(0.11266830487101683), 'MBE': np.float64(-0.010234246131323042), 'NSE': np.float64(-176.65426809731196)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# {'R2': 0.66039324189136, 'RMSE': np.float64(0.11019630953922004), 'MBE': np.float64(0.0002831655810672324), 'NSE': np.float64(-184.8744491195594)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# {'R2': -0.02770344425850446, 'RMSE': np.float64(0.19169588676708152), 'MBE': np.float64(0.031473552929697765), 'NSE': np.float64(-136.7122615306396)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# {'R2': 0.34946690201820096, 'RMSE': np.float64(0.1525153610128904), 'MBE': np.float64(0.08521841892810111), 'NSE': np.float64(-185.2378038283132)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# {'R2': 0.6500006299686443, 'RMSE': np.float64(0.11186971189143192), 'MBE': np.float64(-0.000796188687334184), 'NSE': np.float64(-179.0558454380134)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step
# {'R2': 0.6525436347963558, 'RMSE': np.float64(0.11146256279823792), 'MBE': np.float64(0.0270895741482823), 'NSE': np.float64(-187.8031712873404)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 60ms/step
# {'R2': 0.6100471292298886, 'RMSE': np.float64(0.11808233956011209), 'MBE': np.float64(0.049398803815789316), 'NSE': np.float64(-190.7056361092313)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 53ms/step
# {'R2': 0.5973752941943056, 'RMSE': np.float64(0.11998559197072778), 'MBE': np.float64(0.03892232214591497), 'NSE': np.float64(-202.8321885659396)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step
# {'R2': 0.6734078090768724, 'RMSE': np.float64(0.1080641859778922), 'MBE': np.float64(0.005440703117012214), 'NSE': np.float64(-189.67768161447003)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# {'R2': -1.8540360288907838, 'RMSE': np.float64(0.31945420849775996), 'MBE': np.float64(0.2574767229431255), 'NSE': np.float64(-381.44082787136495)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step
# {'R2': 0.6233391747995984, 'RMSE': np.float64(0.11605239700993089), 'MBE': np.float64(0.013568240686905155), 'NSE': np.float64(-185.42404395354245)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# {'R2': 0.7100099861274758, 'RMSE': np.float64(0.10182874930429604), 'MBE': np.float64(-0.00739333396717583), 'NSE': np.float64(-205.58563598572175)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step
# {'R2': 0.6062190560490673, 'RMSE': np.float64(0.11866051697711935), 'MBE': np.float64(-0.03416834456452581), 'NSE': np.float64(-174.27238768030588)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 74ms/step
# {'R2': 0.5577361419677476, 'RMSE': np.float64(0.1257533645016633), 'MBE': np.float64(-0.0045765631297976775), 'NSE': np.float64(-171.605295948523)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step
# {'R2': 0.631173633944502, 'RMSE': np.float64(0.11483912322637133), 'MBE': np.float64(-0.001099960089743018), 'NSE': np.float64(-188.75296189240814)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# {'R2': 0.6844940373964659, 'RMSE': np.float64(0.10621422237766), 'MBE': np.float64(-0.011711053845721268), 'NSE': np.float64(-185.71941974906565)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step
# {'R2': 0.5628159551440826, 'RMSE': np.float64(0.1250290813493673), 'MBE': np.float64(0.07254264585372328), 'NSE': np.float64(-240.72199237597712)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step
# {'R2': 0.5406713503552723, 'RMSE': np.float64(0.12815650511605858), 'MBE': np.float64(-0.02250416650891203), 'NSE': np.float64(-163.15830012624093)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step
# {'R2': 0.6483995224253536, 'RMSE': np.float64(0.11212529958197542), 'MBE': np.float64(-0.03533396065425414), 'NSE': np.float64(-200.36171533480336)}

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units  dropout_rate        R2  \
# 0      100          0.001      adam          16           0.0  0.680187
# 1      100          0.001      adam          16           0.1  0.652530
# 2      100          0.001      adam          16           0.2  0.501179
# 3      100          0.001      adam          32           0.0  0.608286
# 4      100          0.001      adam          32           0.1  0.621548
# 5      100          0.001      adam          32           0.2  0.645232
# 6      100          0.001      adam          64           0.0  0.561670
# 7      100          0.001      adam          64           0.1  0.600837
# 8      100          0.001      adam          64           0.2  0.547692
# 9      100          0.001   rmsprop          16           0.0  0.711817
# 10     100          0.001   rmsprop          16           0.1  0.695303
# 11     100          0.001   rmsprop          16           0.2  0.490482
# 12     100          0.001   rmsprop          32           0.0  0.715492
# 13     100          0.001   rmsprop          32           0.1  0.625863
# 14     100          0.001   rmsprop          32           0.2  0.557630
# 15     100          0.001   rmsprop          64           0.0  0.662174
# 16     100          0.001   rmsprop          64           0.1  0.706654
# 17     100          0.001   rmsprop          64           0.2  0.644986
# 18     100          0.010      adam          16           0.0  0.660393
# 19     100          0.010      adam          16           0.1 -0.027703
# 20     100          0.010      adam          16           0.2  0.349467
# 21     100          0.010      adam          32           0.0  0.650001
# 22     100          0.010      adam          32           0.1  0.652544
# 23     100          0.010      adam          32           0.2  0.610047
# 24     100          0.010      adam          64           0.0  0.597375
# 25     100          0.010      adam          64           0.1  0.673408
# 26     100          0.010      adam          64           0.2 -1.854036
# 27     100          0.010   rmsprop          16           0.0  0.623339
# 28     100          0.010   rmsprop          16           0.1  0.710010
# 29     100          0.010   rmsprop          16           0.2  0.606219
# 30     100          0.010   rmsprop          32           0.0  0.557736
# 31     100          0.010   rmsprop          32           0.1  0.631174
# 32     100          0.010   rmsprop          32           0.2  0.684494
# 33     100          0.010   rmsprop          64           0.0  0.562816
# 34     100          0.010   rmsprop          64           0.1  0.540671
# 35     100          0.010   rmsprop          64           0.2  0.648400
#
#         RMSE       MBE         NSE
# 0   0.106937 -0.016560 -202.607256
# 1   0.111465 -0.034279 -189.976436
# 2   0.133552 -0.037632 -161.266084
# 3   0.118349 -0.001202 -183.974853
# 4   0.116328 -0.006943 -175.548494
# 5   0.112629 -0.010334 -200.220040
# 6   0.125193 -0.008495 -182.892475
# 7   0.119469 -0.022349 -175.756821
# 8   0.127173 -0.014847 -172.499518
# 9   0.101511 -0.012905 -198.955924
# 10  0.104379 -0.014085 -195.652966
# 11  0.134977  0.043338 -167.474320
# 12  0.100862  0.008258 -202.185681
# 13  0.115663  0.026962 -180.144376
# 14  0.125769  0.022863 -165.533162
# 15  0.109907  0.007409 -184.044196
# 16  0.102416 -0.010127 -200.456073
# 17  0.112668 -0.010234 -176.654268
# 18  0.110196  0.000283 -184.874449
# 19  0.191696  0.031474 -136.712262
# 20  0.152515  0.085218 -185.237804
# 21  0.111870 -0.000796 -179.055845
# 22  0.111463  0.027090 -187.803171
# 23  0.118082  0.049399 -190.705636
# 24  0.119986  0.038922 -202.832189
# 25  0.108064  0.005441 -189.677682
# 26  0.319454  0.257477 -381.440828
# 27  0.116052  0.013568 -185.424044
# 28  0.101829 -0.007393 -205.585636
# 29  0.118661 -0.034168 -174.272388
# 30  0.125753 -0.004577 -171.605296
# 31  0.114839 -0.001100 -188.752962
# 32  0.106214 -0.011711 -185.719420
# 33  0.125029  0.072543 -240.721992
# 34  0.128157 -0.022504 -163.158300
# 35  0.112125 -0.035334 -200.361715

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{best_config['dropout_rate']}"
if best_config['dropout_rate'] == 0.0:
    best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{0}"
best_model = models[best_model_name]
best_history = all_history[best_model_name]
best_r2_callback = all_r2_callback[best_model_name]

best_model.save("kebun_jeruk.keras")

# %%
best_model_name
# Out:
# 'epochs_100_lr_0.001_opt_rmsprop_units_32_do_0'

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0084
# Test Loss: 0.01017308421432972

# %%
from tensorflow.keras.models import load_model

best_model = load_model("kebun_jeruk.keras")

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)

# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mae = mean_absolute_error(test_true, test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²  : {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE : {test_mae:.4f}")
print(f"Test NSE : {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step
#
# Testing Metrics:
# Test R²  : 0.7155
# Test RMSE: 0.1009
# Test MAE : 0.0717
# Test NSE : -202.1857

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.xticks(rotation=45) 
import matplotlib.dates as mdates
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=90)) 
plt.legend()
plt.show()
# Out:
#  33/264 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
df_results.to_csv("kebun_jeruk results.csv", index=False)

# %%
loss = best_history.history['loss']
val_loss = best_history.history['val_loss']
r2_scores = best_r2_callback.r2_scores

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()
