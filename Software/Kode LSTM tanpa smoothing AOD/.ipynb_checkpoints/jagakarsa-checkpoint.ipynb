# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\AData\\kuliah\\sem 7\\Tugas Akhir\\Kode Program\\data gabungan aod cuaca pm2.5\\jagakarsa.csv"
df_cleaned = pd.read_csv(path)
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD'] # untuk nilai 0
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA
    
df_cleaned.replace("-", pd.NA, inplace=True)

columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD'] # untuk interpolasi
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

df_cleaned = df_cleaned.dropna()

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity  precip  windspeed  \
# 11     52.750000  2022-01-12  26.2  24.1      88.8  17.026       20.6
# 12     54.666667  2022-01-13  26.9  24.1      85.6   5.949       24.1
# 13     60.916667  2022-01-14  26.7  24.3      87.3  14.183       19.0
# 14     68.833333  2022-01-15  26.7  24.3      87.2   5.342       16.6
# 15     80.916667  2022-01-16  26.9  25.2      90.3   6.368       11.6
# ...          ...         ...   ...   ...       ...     ...        ...
# 1091   82.888889  2024-12-27  28.8  23.2      73.2   0.000       16.7
# 1092   74.833333  2024-12-28  29.4  22.2      66.7   0.044       21.2
# 1093   66.777778  2024-12-29  28.9  23.5      73.5   0.051       15.2
# 1094   58.722222  2024-12-30  27.8  23.0      75.5   3.335       29.9
# 1095   50.666667  2024-12-31  27.9  22.9      75.2   4.007       23.4
#
#            AOD
# 11    0.109585
# 12    0.110431
# 13    0.111277
# 14    0.112123
# 15    0.112969
# ...        ...
# 1091  0.018800
# 1092  0.003000
# 1093  0.003000
# 1094  0.003000
# 1095  0.003000
#
# [1085 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (183, 33, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.callbacks import Callback
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(dropout_rate),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(dropout_rate),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model


def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    all_history = {}
    all_r2_callback = {}
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    for dropout_rate in param_grid['dropout_rate']:

                        class R2History(Callback):
                            def __init__(self, val_gen):
                                self.val_gen = val_gen
                                self.r2_scores = []

                            def on_epoch_end(self, epoch, logs=None):
                                val_pred = self.model.predict(self.val_gen, verbose=0)
                                val_true_list = []
                                for i in range(len(test_gen)):
                                    _, y = val_gen[i]
                                    val_true_list.append(y)
                                val_true = np.hstack(val_true_list)
                                r2 = r2_score(val_true, val_pred)
                                self.r2_scores.append(r2)

                        r2_callback = R2History(val_gen)
                        config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}_do_{dropout_rate}"
                        print(f"\nTraining model dengan {config_name}")

                        model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate)  # ✅ Update
                        history = model.fit(train_gen, validation_data=val_gen, epochs=1, verbose=0,callbacks=[r2_callback])
                        history = model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0, callbacks=[r2_callback])

                        metrics = evaluate_model(model, test_gen)
                        print(metrics)

                        results.append({
                            'epochs': epochs,
                            'learning_rate': learning_rate,
                            'optimizer': optimizer,
                            'lstm_units': lstm_units,
                            'dropout_rate': dropout_rate,  
                            'R2': metrics['R2'],
                            'RMSE': metrics['RMSE'],
                            'MBE': metrics['MBE'],
                            'NSE': metrics['NSE']
                        })
                        models[config_name] = model
                        all_history[config_name] = history
                        all_r2_callback[config_name] = r2_callback

    return results, models, all_history, all_r2_callback

# %%
param_grid = {
    'epochs': [100],
    'learning_rate': [0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64],
    'dropout_rate': [0, 0.1, 0.2]
}

grid_results, models, all_history, all_r2_callback = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  9/34 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# {'R2': 0.6329420230910016, 'RMSE': np.float64(0.0741300673579226), 'MBE': np.float64(-0.004835885324311654), 'NSE': np.float64(-210.4259957606179)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step
# {'R2': 0.5312457605974883, 'RMSE': np.float64(0.08377215077178733), 'MBE': np.float64(-0.026183375811125672), 'NSE': np.float64(-189.91500968476572)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# {'R2': 0.5501695860983932, 'RMSE': np.float64(0.08206377088858327), 'MBE': np.float64(0.00036625105347842736), 'NSE': np.float64(-170.3867022252563)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step
# {'R2': 0.5787474476595574, 'RMSE': np.float64(0.0794142308640493), 'MBE': np.float64(-0.002161497417397327), 'NSE': np.float64(-189.18469265650677)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step
# {'R2': 0.5934615211116099, 'RMSE': np.float64(0.07801496003898487), 'MBE': np.float64(0.0011196313004948753), 'NSE': np.float64(-197.79342535254239)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 84ms/step
# {'R2': 0.4618801291076806, 'RMSE': np.float64(0.08975663783138986), 'MBE': np.float64(-0.021528477683612525), 'NSE': np.float64(-161.1091075094099)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step
# {'R2': 0.4292952534800343, 'RMSE': np.float64(0.09243422487730987), 'MBE': np.float64(-0.015671027602271227), 'NSE': np.float64(-204.69410138199538)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step
# {'R2': 0.4603660446886043, 'RMSE': np.float64(0.0898828213037725), 'MBE': np.float64(-0.005034821163978904), 'NSE': np.float64(-174.19550061091942)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# {'R2': 0.4742309047669303, 'RMSE': np.float64(0.08872062422047723), 'MBE': np.float64(-0.012212988072983228), 'NSE': np.float64(-173.12995324375262)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 39ms/step
# {'R2': 0.5859117897782715, 'RMSE': np.float64(0.07873602656837747), 'MBE': np.float64(-0.02981621507983853), 'NSE': np.float64(-221.5367631081871)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# {'R2': 0.5808998993489547, 'RMSE': np.float64(0.0792110816975697), 'MBE': np.float64(0.025054695751513253), 'NSE': np.float64(-196.61463906908423)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step
# {'R2': 0.3945579990069368, 'RMSE': np.float64(0.09520578413109847), 'MBE': np.float64(0.04361961123063239), 'NSE': np.float64(-182.17287038137556)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 80ms/step
# {'R2': 0.531044374909827, 'RMSE': np.float64(0.08379014388970334), 'MBE': np.float64(-0.02727419574464689), 'NSE': np.float64(-187.45203040863103)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 58ms/step
# {'R2': 0.5552543906348015, 'RMSE': np.float64(0.08159863542429965), 'MBE': np.float64(-0.010313275284458316), 'NSE': np.float64(-173.50971692802148)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step
# {'R2': 0.4515487348038313, 'RMSE': np.float64(0.09061416290324317), 'MBE': np.float64(0.028102035258516584), 'NSE': np.float64(-168.65104961866703)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 61ms/step
# {'R2': 0.6135755173846358, 'RMSE': np.float64(0.07606053546270057), 'MBE': np.float64(-0.014955858380663618), 'NSE': np.float64(-202.36291878240584)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 94ms/step
# {'R2': 0.5501254516996157, 'RMSE': np.float64(0.08206779656831097), 'MBE': np.float64(-0.008723788881206554), 'NSE': np.float64(-182.33536038323237)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step
# {'R2': 0.5022313492723416, 'RMSE': np.float64(0.08632584381297664), 'MBE': np.float64(-0.021969842961201785), 'NSE': np.float64(-189.78260461390406)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# {'R2': 0.5177490755040729, 'RMSE': np.float64(0.08496960432204566), 'MBE': np.float64(-0.026050306884826877), 'NSE': np.float64(-225.52504342512276)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step
# {'R2': 0.5266976612454135, 'RMSE': np.float64(0.0841775704073027), 'MBE': np.float64(-0.009369794474335611), 'NSE': np.float64(-175.85775935929786)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 78ms/step
# {'R2': 0.5204221773342615, 'RMSE': np.float64(0.08473378515034571), 'MBE': np.float64(-0.01713113545187627), 'NSE': np.float64(-175.43163722600642)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 82ms/step
# {'R2': 0.4377513730739917, 'RMSE': np.float64(0.09174687131792265), 'MBE': np.float64(-0.04079072013425547), 'NSE': np.float64(-219.64851502542322)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step
# {'R2': 0.5867835740630796, 'RMSE': np.float64(0.0786531010049809), 'MBE': np.float64(-0.006296288528275887), 'NSE': np.float64(-199.59470742691533)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 68ms/step
# {'R2': 0.4313566641503712, 'RMSE': np.float64(0.09226713561248077), 'MBE': np.float64(0.052513291669698925), 'NSE': np.float64(-266.59967888120144)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 64ms/step
# {'R2': 0.5562520561943907, 'RMSE': np.float64(0.08150706189093175), 'MBE': np.float64(0.014741553160065281), 'NSE': np.float64(-211.4102517982621)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 65ms/step
# {'R2': 0.5866068533030715, 'RMSE': np.float64(0.07866991803972768), 'MBE': np.float64(-0.004542787045411964), 'NSE': np.float64(-188.59228229293313)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step
# {'R2': 0.5262177639935435, 'RMSE': np.float64(0.08422023483838906), 'MBE': np.float64(0.01571861451535719), 'NSE': np.float64(-175.45661184495307)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': -0.06382616476425862, 'RMSE': np.float64(0.12620088347756395), 'MBE': np.float64(-0.030911952396553706), 'NSE': np.float64(-141.5527060784106)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step
# {'R2': 0.5579011601424589, 'RMSE': np.float64(0.08135546825244884), 'MBE': np.float64(-0.00727252965248596), 'NSE': np.float64(-196.89574167100025)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step
# {'R2': 0.5558388773738935, 'RMSE': np.float64(0.08154499914399747), 'MBE': np.float64(-0.007908836813731734), 'NSE': np.float64(-171.73699399815166)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 43ms/step
# {'R2': 0.502726606856919, 'RMSE': np.float64(0.08628288794523796), 'MBE': np.float64(-0.030790651161895628), 'NSE': np.float64(-229.44339281073843)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step
# {'R2': 0.5841072473700235, 'RMSE': np.float64(0.0789074007316805), 'MBE': np.float64(-0.010377935426175457), 'NSE': np.float64(-189.16965619914623)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 67ms/step
# {'R2': 0.5126015013369118, 'RMSE': np.float64(0.0854218858332029), 'MBE': np.float64(-0.0350081595081828), 'NSE': np.float64(-197.54985390118782)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# {'R2': 0.48642491317148007, 'RMSE': np.float64(0.0876857529466348), 'MBE': np.float64(-0.03293980738715703), 'NSE': np.float64(-208.88507010955786)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step
# {'R2': 0.4202797478533912, 'RMSE': np.float64(0.09316146248788769), 'MBE': np.float64(-0.05376062433816857), 'NSE': np.float64(-229.1859402018827)}
#
# Training model dengan epochs_100_lr_0.01_opt_rmsprop_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step
# {'R2': 0.47746449915005984, 'RMSE': np.float64(0.08844737786570392), 'MBE': np.float64(-0.04096819318647959), 'NSE': np.float64(-192.66721042337014)}

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units  dropout_rate        R2  \
# 0      100          0.001      adam          16           0.0  0.632942
# 1      100          0.001      adam          16           0.1  0.531246
# 2      100          0.001      adam          16           0.2  0.550170
# 3      100          0.001      adam          32           0.0  0.578747
# 4      100          0.001      adam          32           0.1  0.593462
# 5      100          0.001      adam          32           0.2  0.461880
# 6      100          0.001      adam          64           0.0  0.429295
# 7      100          0.001      adam          64           0.1  0.460366
# 8      100          0.001      adam          64           0.2  0.474231
# 9      100          0.001   rmsprop          16           0.0  0.585912
# 10     100          0.001   rmsprop          16           0.1  0.580900
# 11     100          0.001   rmsprop          16           0.2  0.394558
# 12     100          0.001   rmsprop          32           0.0  0.531044
# 13     100          0.001   rmsprop          32           0.1  0.555254
# 14     100          0.001   rmsprop          32           0.2  0.451549
# 15     100          0.001   rmsprop          64           0.0  0.613576
# 16     100          0.001   rmsprop          64           0.1  0.550125
# 17     100          0.001   rmsprop          64           0.2  0.502231
# 18     100          0.010      adam          16           0.0  0.517749
# 19     100          0.010      adam          16           0.1  0.526698
# 20     100          0.010      adam          16           0.2  0.520422
# 21     100          0.010      adam          32           0.0  0.437751
# 22     100          0.010      adam          32           0.1  0.586784
# 23     100          0.010      adam          32           0.2  0.431357
# 24     100          0.010      adam          64           0.0  0.556252
# 25     100          0.010      adam          64           0.1  0.586607
# 26     100          0.010      adam          64           0.2  0.526218
# 27     100          0.010   rmsprop          16           0.0 -0.063826
# 28     100          0.010   rmsprop          16           0.1  0.557901
# 29     100          0.010   rmsprop          16           0.2  0.555839
# 30     100          0.010   rmsprop          32           0.0  0.502727
# 31     100          0.010   rmsprop          32           0.1  0.584107
# 32     100          0.010   rmsprop          32           0.2  0.512602
# 33     100          0.010   rmsprop          64           0.0  0.486425
# 34     100          0.010   rmsprop          64           0.1  0.420280
# 35     100          0.010   rmsprop          64           0.2  0.477464
#
#         RMSE       MBE         NSE
# 0   0.074130 -0.004836 -210.425996
# 1   0.083772 -0.026183 -189.915010
# 2   0.082064  0.000366 -170.386702
# 3   0.079414 -0.002161 -189.184693
# 4   0.078015  0.001120 -197.793425
# 5   0.089757 -0.021528 -161.109108
# 6   0.092434 -0.015671 -204.694101
# 7   0.089883 -0.005035 -174.195501
# 8   0.088721 -0.012213 -173.129953
# 9   0.078736 -0.029816 -221.536763
# 10  0.079211  0.025055 -196.614639
# 11  0.095206  0.043620 -182.172870
# 12  0.083790 -0.027274 -187.452030
# 13  0.081599 -0.010313 -173.509717
# 14  0.090614  0.028102 -168.651050
# 15  0.076061 -0.014956 -202.362919
# 16  0.082068 -0.008724 -182.335360
# 17  0.086326 -0.021970 -189.782605
# 18  0.084970 -0.026050 -225.525043
# 19  0.084178 -0.009370 -175.857759
# 20  0.084734 -0.017131 -175.431637
# 21  0.091747 -0.040791 -219.648515
# 22  0.078653 -0.006296 -199.594707
# 23  0.092267  0.052513 -266.599679
# 24  0.081507  0.014742 -211.410252
# 25  0.078670 -0.004543 -188.592282
# 26  0.084220  0.015719 -175.456612
# 27  0.126201 -0.030912 -141.552706
# 28  0.081355 -0.007273 -196.895742
# 29  0.081545 -0.007909 -171.736994
# 30  0.086283 -0.030791 -229.443393
# 31  0.078907 -0.010378 -189.169656
# 32  0.085422 -0.035008 -197.549854
# 33  0.087686 -0.032940 -208.885070
# 34  0.093161 -0.053761 -229.185940
# 35  0.088447 -0.040968 -192.667210

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{best_config['dropout_rate']}"
if best_config['dropout_rate'] == 0.0:
    best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{0}"
best_model = models[best_model_name]
best_history = all_history[best_model_name]
best_r2_callback = all_r2_callback[best_model_name]


best_model.save("jagakarsa.keras")

# %%
best_model_name
# Out:
# 'epochs_100_lr_0.001_opt_adam_units_16_do_0'

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0044
# Test Loss: 0.005495266057550907

# %%
from tensorflow.keras.models import load_model

best_model = load_model("jagakarsa.keras")

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)

# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mae = mean_absolute_error(test_true, test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²  : {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE : {test_mae:.4f}")
print(f"Test NSE : {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 57ms/step
#
# Testing Metrics:
# Test R²  : 0.6329
# Test RMSE: 0.0741
# Test MAE : 0.0550
# Test NSE : -210.4260

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
import matplotlib.dates as mdates
plt.xticks(rotation=45)  
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=90)) 
plt.legend()
plt.show()
# Out:
#  30/264 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %%
df_results.to_csv("jagakarsa results.csv", index=False)

# %%
loss = best_history.history['loss']
val_loss = best_history.history['val_loss']
r2_scores = best_r2_callback.r2_scores

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()
