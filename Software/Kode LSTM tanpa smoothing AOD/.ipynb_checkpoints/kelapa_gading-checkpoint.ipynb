# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.preprocessing.sequence import TimeseriesGenerator
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
path = "C:\\Users\\User\\Downloads\\predict_model\\Data Penelitian\\data gabungan aod cuaca pm2.5\\kelapa_gading.csv"
df_cleaned = pd.read_csv(path)
columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'AOD'] # untuk nilai 0
for col in columns:
    df_cleaned.loc[df_cleaned[col] == 0, col] = pd.NA
    
df_cleaned.replace("-", pd.NA, inplace=True)

columns = ['ISPU PM2.5', 'temp', 'dew', 'humidity', 'windspeed', 'precip', 'AOD'] # untuk interpolasi
for col in columns:
    df_cleaned[col] = df_cleaned[col].interpolate(method='linear')

df_cleaned = df_cleaned.dropna()

# %%
df_cleaned
# Out:
#       ISPU PM2.5    datetime  temp   dew  humidity  precip  windspeed     AOD
# 11     50.750000  2022-01-12  26.5  24.2      88.2  11.109       20.6  0.6034
# 12     53.750000  2022-01-13  27.1  24.3      85.2   9.373       29.9  0.5804
# 13     54.166667  2022-01-14  26.8  24.4      87.0  23.019       19.0  0.5574
# 14     52.083333  2022-01-15  27.0  24.4      86.7   4.747       16.6  0.5344
# 15     52.991667  2022-01-16  27.2  25.3      89.8   9.154       11.8  0.5114
# ...          ...         ...   ...   ...       ...     ...        ...     ...
# 1091   54.444444  2024-12-27  29.0  23.6      73.5   0.000       14.9  0.5484
# 1092   50.354167  2024-12-28  29.6  22.6      67.3   0.004       21.2  0.6132
# 1093   46.263889  2024-12-29  29.1  23.9      74.0   0.166       15.2  0.6616
# 1094   42.173611  2024-12-30  28.1  23.2      75.2   1.244       29.9  1.0880
# 1095   38.083333  2024-12-31  28.2  23.2      75.5   2.258       23.4  1.5144
#
# [1085 rows x 8 columns]

# %%
df = df_cleaned

features = ["temp", "dew", "humidity", "precip", "windspeed", "AOD", "ISPU PM2.5"]
target = "ISPU PM2.5"

# Normalisasi data
scaler = MinMaxScaler()
df_scaled = scaler.fit_transform(df[features])

# Tentukan lookback (jumlah timestep sebelumnya digunakan untuk prediksi)
lookback = 30

# Bagi data menjadi training (70%), validasi (15%), dan testing (15%)
train_size = int(len(df_scaled) * 0.7)
val_size = int(len(df_scaled) * 0.15)

train_data = df_scaled[:train_size]
val_data = df_scaled[train_size:train_size+val_size]
test_data = df_scaled[train_size+val_size:]

# Gunakan TimeseriesGenerator untuk membentuk data dalam format sekuensial
train_gen = TimeseriesGenerator(train_data, train_data[:, 6], length=lookback, batch_size=4)
val_gen = TimeseriesGenerator(val_data, val_data[:, 6], length=lookback, batch_size=4)
test_gen = TimeseriesGenerator(test_data, test_data[:, 6], length=lookback, batch_size=4)

# Cek bentuk data generator
len(train_gen), len(val_gen), len(test_gen)
# Out:
# (183, 33, 34)

# %%
import pandas as pd
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam, RMSprop
from tensorflow.keras import Input
from sklearn.metrics import mean_squared_error, r2_score
from tensorflow.keras.callbacks import Callback
import numpy as np

def build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate):
    model = Sequential([
        Input(shape=input_shape),
        LSTM(lstm_units, activation='relu', return_sequences=True),
        Dropout(dropout_rate),
        LSTM(lstm_units, activation='relu', return_sequences=False),
        Dropout(dropout_rate),
        Dense(25, activation='relu'),
        Dense(1)
    ])
    
    opt = Adam(learning_rate=learning_rate) if optimizer == 'adam' else RMSprop(learning_rate=learning_rate)
    model.compile(optimizer=opt, loss='mse')
    return model


def evaluate_model(model, test_gen):
    test_pred = model.predict(test_gen)
    
    test_true_list = []
    for i in range(len(test_gen)):  
        _, y = test_gen[i]  # Ambil hanya nilai target dari generator
        test_true_list.append(y)
    
    test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
    
    test_r2 = r2_score(test_true, test_pred)
    test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
    test_mbe = np.mean(test_true - test_pred)
    test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))
    
    return {'R2': test_r2, 'RMSE': test_rmse, 'MBE': test_mbe, 'NSE': test_nse}

def grid_search_lstm(train_gen, val_gen, test_gen, input_shape, param_grid):
    results = []
    models = {}
    all_history = {}
    all_r2_callback = {}
    for epochs in param_grid['epochs']:
        for learning_rate in param_grid['learning_rate']:
            for optimizer in param_grid['optimizer']:
                for lstm_units in param_grid['lstm_units']:
                    for dropout_rate in param_grid['dropout_rate']:

                        class R2History(Callback):
                            def __init__(self, val_gen):
                                self.val_gen = val_gen
                                self.r2_scores = []

                            def on_epoch_end(self, epoch, logs=None):
                                val_pred = self.model.predict(self.val_gen, verbose=0)
                                val_true_list = []
                                for i in range(len(test_gen)):
                                    _, y = val_gen[i]
                                    val_true_list.append(y)
                                val_true = np.hstack(val_true_list)
                                r2 = r2_score(val_true, val_pred)
                                self.r2_scores.append(r2)

                        r2_callback = R2History(val_gen)
                        config_name = f"epochs_{epochs}_lr_{learning_rate}_opt_{optimizer}_units_{lstm_units}_do_{dropout_rate}"
                        print(f"\nTraining model dengan {config_name}")

                        model = build_lstm_model(input_shape, lstm_units, optimizer, learning_rate, dropout_rate)  # ✅ Update
                        history = model.fit(train_gen, validation_data=val_gen, epochs=1, verbose=0,callbacks=[r2_callback])
                        history = model.fit(train_gen, validation_data=val_gen, epochs=epochs, verbose=0, callbacks=[r2_callback])

                        metrics = evaluate_model(model, test_gen)
                        print(metrics)

                        results.append({
                            'epochs': epochs,
                            'learning_rate': learning_rate,
                            'optimizer': optimizer,
                            'lstm_units': lstm_units,
                            'dropout_rate': dropout_rate,  
                            'R2': metrics['R2'],
                            'RMSE': metrics['RMSE'],
                            'MBE': metrics['MBE'],
                            'NSE': metrics['NSE']
                        })
                        models[config_name] = model
                        all_history[config_name] = history
                        all_r2_callback[config_name] = r2_callback

    return results, models, all_history, all_r2_callback

# %%
param_grid = {
    'epochs': [100],
    'learning_rate': [0.001, 0.01],
    'optimizer': ['adam', 'rmsprop'],
    'lstm_units': [16, 32, 64],
    'dropout_rate': [0, 0.1, 0.2]
}

grid_results, models, all_history, all_r2_callback = grid_search_lstm(train_gen, val_gen, test_gen, (lookback, len(features)), param_grid)

df_results = pd.DataFrame(grid_results)
# Out:
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
#  1/34 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step
# {'R2': 0.7044500199413093, 'RMSE': np.float64(0.10088344006520447), 'MBE': np.float64(-0.03365792069694835), 'NSE': np.float64(-200.40903030498544)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step
# {'R2': 0.6910255922468391, 'RMSE': np.float64(0.10314915392147574), 'MBE': np.float64(-0.0007552365786276555), 'NSE': np.float64(-177.94466083567823)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step
# {'R2': 0.5935463219922447, 'RMSE': np.float64(0.11830686460230282), 'MBE': np.float64(0.02751065098694955), 'NSE': np.float64(-169.0355456047082)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step
# {'R2': 0.6500285222810211, 'RMSE': np.float64(0.10977937185018329), 'MBE': np.float64(-0.03529208367272934), 'NSE': np.float64(-207.40062120859292)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step
# {'R2': 0.6485615828759443, 'RMSE': np.float64(0.11000920670252852), 'MBE': np.float64(-0.04189637150170143), 'NSE': np.float64(-196.73431781904335)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step
# {'R2': 0.5409364873762978, 'RMSE': np.float64(0.12573054658050195), 'MBE': np.float64(-0.026096420749016108), 'NSE': np.float64(-163.3986441472804)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step
# {'R2': 0.6895284362056502, 'RMSE': np.float64(0.10339875995886022), 'MBE': np.float64(-0.02830140117221749), 'NSE': np.float64(-204.94335635738807)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step
# {'R2': 0.6458907339373344, 'RMSE': np.float64(0.11042643747908411), 'MBE': np.float64(-0.031177048721526438), 'NSE': np.float64(-199.34067360097765)}
#
# Training model dengan epochs_100_lr_0.001_opt_adam_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step
# {'R2': 0.6905773765307202, 'RMSE': np.float64(0.10322394380019538), 'MBE': np.float64(-0.01340113282481182), 'NSE': np.float64(-195.09400039775153)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 56ms/step
# {'R2': 0.6276978827423934, 'RMSE': np.float64(0.11322756527903081), 'MBE': np.float64(-0.06446289996435338), 'NSE': np.float64(-216.44702810373946)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step
# {'R2': 0.7361819676531278, 'RMSE': np.float64(0.09531399088782369), 'MBE': np.float64(-0.004024154906948458), 'NSE': np.float64(-204.21167071872034)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_16_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step
# {'R2': 0.6519382620420875, 'RMSE': np.float64(0.10947943766321196), 'MBE': np.float64(0.028498909564054375), 'NSE': np.float64(-181.17856180876646)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step
# {'R2': 0.7123878184637693, 'RMSE': np.float64(0.09951946987243479), 'MBE': np.float64(-0.01234978551127963), 'NSE': np.float64(-186.87062228838465)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# {'R2': 0.7024726281275655, 'RMSE': np.float64(0.10122036029128281), 'MBE': np.float64(-0.013576004734786045), 'NSE': np.float64(-187.89121321112071)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_32_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 30ms/step
# {'R2': 0.6609510303775459, 'RMSE': np.float64(0.10805270169933612), 'MBE': np.float64(-0.04185149609875269), 'NSE': np.float64(-193.13540766747295)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 55ms/step
# {'R2': 0.6804287606035857, 'RMSE': np.float64(0.10490308479515317), 'MBE': np.float64(-0.04625139265640404), 'NSE': np.float64(-211.37470121513402)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.1
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step
# {'R2': 0.720894470033071, 'RMSE': np.float64(0.09803668924905466), 'MBE': np.float64(-0.0028502065104507594), 'NSE': np.float64(-192.16333608300656)}
#
# Training model dengan epochs_100_lr_0.001_opt_rmsprop_units_64_do_0.2
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 52ms/step
# {'R2': 0.6456165271347803, 'RMSE': np.float64(0.11046918391880177), 'MBE': np.float64(-0.04639397830938171), 'NSE': np.float64(-204.17144212613454)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step
# {'R2': 0.6902622196009343, 'RMSE': np.float64(0.10327649888069107), 'MBE': np.float64(-0.018427671250228907), 'NSE': np.float64(-199.03651020865286)}
#
# Training model dengan epochs_100_lr_0.01_opt_adam_units_16_do_0.1

# %%
df_results
# Out:
#     epochs  learning_rate optimizer  lstm_units  dropout_rate        R2  \
# 0      100          0.001      adam          16           0.0  0.704450
# 1      100          0.001      adam          16           0.1  0.691026
# 2      100          0.001      adam          16           0.2  0.593546
# 3      100          0.001      adam          32           0.0  0.650029
# 4      100          0.001      adam          32           0.1  0.648562
# 5      100          0.001      adam          32           0.2  0.540936
# 6      100          0.001      adam          64           0.0  0.689528
# 7      100          0.001      adam          64           0.1  0.645891
# 8      100          0.001      adam          64           0.2  0.690577
# 9      100          0.001   rmsprop          16           0.0  0.627698
# 10     100          0.001   rmsprop          16           0.1  0.736182
# 11     100          0.001   rmsprop          16           0.2  0.651938
# 12     100          0.001   rmsprop          32           0.0  0.712388
# 13     100          0.001   rmsprop          32           0.1  0.702473
# 14     100          0.001   rmsprop          32           0.2  0.660951
# 15     100          0.001   rmsprop          64           0.0  0.680429
# 16     100          0.001   rmsprop          64           0.1  0.720894
# 17     100          0.001   rmsprop          64           0.2  0.645617
# 18     100          0.010      adam          16           0.0  0.690262
# 19     100          0.010      adam          16           0.1  0.659748
# 20     100          0.010      adam          16           0.2  0.687532
# 21     100          0.010      adam          32           0.0 -0.461218
# 22     100          0.010      adam          32           0.1  0.664806
# 23     100          0.010      adam          32           0.2  0.651068
# 24     100          0.010      adam          64           0.0  0.704799
# 25     100          0.010      adam          64           0.1  0.777444
# 26     100          0.010      adam          64           0.2  0.751108
# 27     100          0.010   rmsprop          16           0.0  0.679517
# 28     100          0.010   rmsprop          16           0.1  0.645433
# 29     100          0.010   rmsprop          16           0.2  0.635210
# 30     100          0.010   rmsprop          32           0.0  0.696078
# 31     100          0.010   rmsprop          32           0.1  0.707164
# 32     100          0.010   rmsprop          32           0.2  0.753369
# 33     100          0.010   rmsprop          64           0.0  0.649300
# 34     100          0.010   rmsprop          64           0.1  0.690932
# 35     100          0.010   rmsprop          64           0.2  0.641680
#
#         RMSE       MBE         NSE
# 0   0.100883 -0.033658 -200.409030
# 1   0.103149 -0.000755 -177.944661
# 2   0.118307  0.027511 -169.035546
# 3   0.109779 -0.035292 -207.400621
# 4   0.110009 -0.041896 -196.734318
# 5   0.125731 -0.026096 -163.398644
# 6   0.103399 -0.028301 -204.943356
# 7   0.110426 -0.031177 -199.340674
# 8   0.103224 -0.013401 -195.094000
# 9   0.113228 -0.064463 -216.447028
# 10  0.095314 -0.004024 -204.211671
# 11  0.109479  0.028499 -181.178562
# 12  0.099519 -0.012350 -186.870622
# 13  0.101220 -0.013576 -187.891213
# 14  0.108053 -0.041851 -193.135408
# 15  0.104903 -0.046251 -211.374701
# 16  0.098037 -0.002850 -192.163336
# 17  0.110469 -0.046394 -204.171442
# 18  0.103276 -0.018428 -199.036510
# 19  0.108244 -0.032473 -197.534077
# 20  0.103731  0.003651 -181.763768
# 21  0.224317  0.014186 -396.501251
# 22  0.107437 -0.043111 -195.933098
# 23  0.109616 -0.062464 -225.092099
# 24  0.100824 -0.051293 -238.844627
# 25  0.087544  0.016558 -226.057665
# 26  0.092578  0.001928 -198.965747
# 27  0.105053 -0.010396 -188.094826
# 28  0.110498  0.028478 -180.179292
# 29  0.112079  0.017218 -169.590831
# 30  0.102302 -0.004648 -200.767176
# 31  0.100419 -0.022372 -191.323583
# 32  0.092157 -0.001555 -196.444693
# 33  0.109894 -0.041902 -231.525749
# 34  0.103165 -0.043723 -205.099873
# 35  0.111081 -0.000005 -177.759663

# %%
best_config = df_results.loc[df_results['R2'].idxmax()]
best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{best_config['dropout_rate']}"
if best_config['dropout_rate'] == 0.0:
    best_model_name = f"epochs_{best_config['epochs']}_lr_{best_config['learning_rate']}_opt_{best_config['optimizer']}_units_{best_config['lstm_units']}_do_{0}"
best_model = models[best_model_name]
best_history = all_history[best_model_name]
best_r2_callback = all_r2_callback[best_model_name]

best_model.save("kelapa_gading.keras")

# %%
best_model_name
# Out:
# 'epochs_100_lr_0.01_opt_adam_units_64_do_0.1'

# %%
# Evaluate model
loss = best_model.evaluate(test_gen)
print(f"Test Loss: {loss}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0079
# Test Loss: 0.007663886994123459

# %%
from tensorflow.keras.models import load_model

best_model = load_model("kelapa_gading.keras")

from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import numpy as np

test_true_list = []
for i in range(len(test_gen)):  
    _, y = test_gen[i]  # Ambil hanya nilai target dari generator
    test_true_list.append(y)

test_true = np.hstack(test_true_list)  # Gabungkan list ke array numpy
test_pred = best_model.predict(test_gen)

# Calculate metrics for testing data
test_r2 = r2_score(test_true, test_pred)
test_rmse = np.sqrt(mean_squared_error(test_true, test_pred))
test_mae = mean_absolute_error(test_true, test_pred)
test_nse = 1 - (np.sum((test_true - test_pred) ** 2) / np.sum((test_true - np.mean(test_true)) ** 2))

# Print metrics for testing data
print("\nTesting Metrics:")
print(f"Test R²  : {test_r2:.4f}")
print(f"Test RMSE: {test_rmse:.4f}")
print(f"Test MAE : {test_mae:.4f}")
print(f"Test NSE : {test_nse:.4f}")
# Out:
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step
#
# Testing Metrics:
# Test R²  : 0.7774
# Test RMSE: 0.0875
# Test MAE : 0.0638
# Test NSE : -226.0577

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.xticks(rotation=45) 
import matplotlib.dates as mdates
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=90)) 
plt.legend()
plt.show()
# Out:
#  28/264 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
df_results.to_csv("kelapa_gading results.csv", index=False)

# %%
# Membuat generator data untuk prediksi
full_gen = TimeseriesGenerator(df_scaled, df_scaled[:, 6], length=lookback, batch_size=4)

# Melakukan prediksi
predictions = best_model.predict(full_gen)

# Membuat array nol dengan jumlah fitur yang sesuai untuk inverse_transform
num_features = len(features)  # Jumlah fitur yang digunakan saat normalisasi
dummy_array = np.zeros((len(predictions), num_features))  # Array nol dengan jumlah fitur yang sama
dummy_array[:, -1] = predictions.flatten()  # Menempatkan prediksi di kolom terakhir (PM2.5)

# Konversi kembali ke skala aslinya
pm25_predictions = scaler.inverse_transform(dummy_array)[:, -1]

# Membuat DataFrame hasil prediksi
prediction_dates = df["datetime"][lookback:].reset_index(drop=True)
pred_df = pd.DataFrame({"datetime": prediction_dates, "Predicted PM2.5": pm25_predictions})

# Plot hasil prediksi vs aktual
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 6))
plt.plot(df["datetime"], df["ISPU PM2.5"], label="Actual PM2.5", alpha=0.5)
plt.plot(pred_df["datetime"], pred_df["Predicted PM2.5"], label="Predicted PM2.5", linestyle="dashed")
plt.xlabel("Date")
plt.ylabel("PM2.5")
plt.title("Predicted vs Actual PM2.5")
plt.xticks(rotation=45) 
import matplotlib.dates as mdates
plt.gca().xaxis.set_major_locator(mdates.DayLocator(interval=90)) 
plt.legend()
plt.show()
# Out:
#  14/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step
# C:\Users\ASUS\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 264/264 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step

# %%
loss = best_history.history['loss']
val_loss = best_history.history['val_loss']
r2_scores = best_r2_callback.r2_scores

plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(loss, label='Train Loss (MSE)')
plt.plot(val_loss, label='Validation Loss (MSE)')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Loss (MSE) over Epochs')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(r2_scores, label='Validation R²', color='green')
plt.xlabel('Epoch')
plt.ylabel('R² Score')
plt.title('Validation R² Score over Epochs')
plt.legend()

plt.tight_layout()
plt.show()
